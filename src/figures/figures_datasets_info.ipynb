# %%
import sys
from pathlib import Path

import pandas as pd

ROOT_DIR = Path.cwd().resolve().parents[1]
if str(ROOT_DIR) not in sys.path:
    sys.path.append(str(ROOT_DIR))
    
print(ROOT_DIR)

CEAS_DIR = ROOT_DIR / "data" / "raw" / "CEAS_08.csv"
ENRON_DIR = ROOT_DIR / "data" / "raw" / "Enron.csv"
NAZARIO_DIR = ROOT_DIR / "data" / "raw" / "Nazario.csv"
SPAM_DIR = ROOT_DIR / "data" / "processed" / "spam.csv"

print("--- CEAS_08.csv Information ---")
df_ceas = pd.read_csv(CEAS_DIR)
print(df_ceas.info(), "\n")

print("--- Enron.csv Information ---")
df_enron = pd.read_csv(ENRON_DIR)
print(df_enron.info(), "\n")

print("--- Nazario.csv Information ---")
df_nazario = pd.read_csv(NAZARIO_DIR)
print(df_nazario.info(), "\n")

print("--- spam.csv Information ---")
df_spam = pd.read_csv(SPAM_DIR)
print(df_spam.info(), "\n")
# Out:
# C:\Users\stick\Desktop\nlp-email-spam-detection
# --- CEAS_08.csv Information ---
# <class 'pandas.DataFrame'>
# RangeIndex: 39154 entries, 0 to 39153
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sender    39154 non-null  str
#  1   receiver  38692 non-null  str
#  2   date      39154 non-null  str
#  3   subject   39126 non-null  str
#  4   body      39154 non-null  str
#  5   label     39154 non-null  int64
#  6   urls      39154 non-null  int64
# dtypes: int64(2), str(5)
# memory usage: 66.3 MB
# None
#
# --- Enron.csv Information ---
# <class 'pandas.DataFrame'>
# RangeIndex: 29767 entries, 0 to 29766
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  29569 non-null  str
#  1   body     29767 non-null  str
#  2   label    29767 non-null  int64
# dtypes: int64(1), str(2)
# memory usage: 43.9 MB
# None
#
# ...
